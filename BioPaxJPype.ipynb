# %%
from jpype import *
from pprint import pprint
import csv

# %%
class ParseBioPax(object):
    def __init__(self, biopax_path=None, ec2rhea_path=None, download_files=False):
        """
        Obtain and instantiate rhea biopax file for to facilitate parsing reactions into python dictionaries
        
        :param biopax_path: local path to bio_pax owl file
        :param ec2rhea_path: local path to ec_numer rhea mapping file
        :param download_files: set to true if you want to check for a new version or don't have the files locally
        :return: paxtools object for parsing reactions
        """
        self.biopax_path = biopax_path
        self.ec2rhea_path = ec2rhea_path
        self.model = self.get_biopax_model()
        self.rhea2ec_map = {}
        self.ec_2_rhea_directional_mapping()
        
        if download_files:
            self.download_ftp_files()
        
    def download_ftp_files(self):        
        biopaxFTP = 'ftp://ftp.ebi.ac.uk/pub/databases/rhea/biopax/rhea-biopax_lite.owl.gz'
        urllib.request.urlretrieve(biopaxFTP, self.biopax_path)
        ec2rheaFTP = 'ftp://ftp.ebi.ac.uk/pub/databases/rhea/tsv/ec-rhea-dir.tsv'
        urllib.request.urlretrieve(ec2rheaFTP, self.ec2rhea_path)
                    
    def ec_2_rhea_directional_mapping(self):
        """
        returns dictionary with rhea key and ec value
        """
        ecmap = {}
        with open(self.ec2rhea_path, 'r') as ec2r:
            csvfile = csv.reader(ec2r, delimiter="\t")
            for line in csvfile:
                self.rhea2ec_map[line[1]] = line[2]
     
    def get_biopax_model(self):
        startJVM(getDefaultJVMPath(), "-ea", "-Xmx1g", "-Djava.class.path=paxtools-5.0.1.jar")
        paxPkg = JPackage("org.biopax.paxtools")
        javaIO = JPackage("java.io")
        io = paxPkg.io.SimpleIOHandler(paxPkg.model.BioPAXLevel.L2)
        fileIS = javaIO.FileInputStream(self.biopax_path)
        return io.convertFromOWL(fileIS)
    
    def get_reaction_by_rhea(self, rheaID):
        """
        input: rhea master Id
        return: reaction element
        """
        rhea_uri = "http://identifiers.org/rhea/{}".format(rheaID)
        return self.model.getByID(rhea_uri)

# %%
class ParseReaction(object):
    def __init__(self, bpmodel, rxn, ec):
        self.model = bpmodel
        self.rxn = rxn
        self.ec = ec
        self.parsed_rxn = {
            'rhea_id': self.get_rxn_rheaID(),
            'ec_number': self.ec,
            'name': self.get_rxn_name(),
            'lefts': self.get_rxn_participants('LEFT'),
            'rights': self.get_rxn_participants('RIGHT'),
            'direction': self.get_rxn_direction()
        }
        
    def get_rxn_rheaID(self):
        rhea_uri = self.rxn.getUri()
        return rhea_uri.split('/')[-1]
    
    def get_rxn_name(self):
        return self.rxn.getNAME()
    
    def get_rxn_participants(self, direction):
        if direction == 'LEFT':
            participants = self.rxn.getLEFT()
        if direction == 'RIGHT':
            participants = self.rxn.getRIGHT()  
        parts_list = []
        for part in participants:
            pe = part.getPHYSICAL_ENTITY()
            peName = pe.getNAME()
            peID = pe.xREF.toString()
            peID = peID.replace('CHEBI:', '').lstrip('[').rstrip(']')
            parts_list.append({peName : peID})
        return parts_list
    
    def get_rxn_direction(self):
        comment = rxn.getCOMMENT()
        comment_array = comment.toArray()
        direction = None
        for com in comment_array:
            if 'RHEA:Direction' in com:
                com = com.split('=')
                direction = com[1]
        return direction

# %%
bp_obj = ParseBioPax(biopax_path='data/rhea-biopax_lite.owl', ec2rhea_path='data/ec-rhea-dir.tsv')

# %%
rhea2ec = bp_obj.rhea2ec_map

# %%
count = 0 
for rhea, ec in rhea2ec.items():
    count += 1
    if count < 100:
        rxn = bp_obj.get_reaction_by_rhea(rheaID=rhea)
        prxn = ParseReaction(bpmodel=bp_obj.model, rxn=rxn, ec=ec)
        pprint(prxn.parsed_rxn)
# Out:
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(1S,2S,4R)-endo-fenchol': 'ChEBI:15405'},
#            {'NADP(+)': 'ChEBI:58349'}],
#  'name': '(1S,2S,4R)-endo-fenchol + NADP(+) => (1S,4R)-fenchone + H(+) + NADPH',
#  'rhea_id': '32336',
#  'rights': [{'NADPH': 'ChEBI:57783'},
#             {'H(+)': 'ChEBI:15378'},
#             {'(1S,4R)-fenchone': 'ChEBI:165'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'D-glyceraldehyde 3-phosphate': 'ChEBI:59776'},
#            {'D-sedoheptulose 7-phosphate': 'ChEBI:57483'}],
#  'name': 'D-glyceraldehyde 3-phosphate + D-sedoheptulose 7-phosphate => '
#          'D-ribose 5-phosphate + D-xylulose 5-phosphate',
#  'rhea_id': '10509',
#  'rights': [{'D-ribose 5-phosphate': 'ChEBI:58273'},
#             {'D-xylulose 5-phosphate': 'ChEBI:57737'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {'dimethylamine': 'ChEBI:58040'},
#            {'oxidized [electron-transfer flavoprotein]': 'ChEBI:57692'},
#            {'H(+)': 'ChEBI:15378'}],
#  'name': 'dimethylamine + H2O + H(+) + oxidized [electron-transfer '
#          'flavoprotein] => formaldehyde + methylamine + reduced '
#          '[electron-transfer flavoprotein]',
#  'rhea_id': '10205',
#  'rights': [{'formaldehyde': 'ChEBI:16842'},
#             {'methylamine': 'ChEBI:59338'},
#             {'reduced [electron-transfer flavoprotein]': 'ChEBI:58307'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'reduced [NADPH--hemoprotein reductase]': 'ChEBI:57618'},
#            {'O2': 'ChEBI:15379'},
#            {'androst-4-ene-3,17-dione': 'ChEBI:16422'}],
#  'name': 'androst-4-ene-3,17-dione + 3 O2 + 3 reduced [NADPH--hemoprotein '
#          'reductase] => estrone + formate + 4 H2O + 4 H(+) + 3 oxidized '
#          '[NADPH--hemoprotein reductase]',
#  'rhea_id': '38196',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'estrone': 'ChEBI:17263'},
#             {'oxidized [NADPH--hemoprotein reductase]': 'ChEBI:58210'},
#             {'H2O': 'ChEBI:15377'},
#             {'formate': 'ChEBI:15740'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'pseudotropine': 'ChEBI:57493'}, {'NADP(+)': 'ChEBI:58349'}],
#  'name': 'NADP(+) + pseudotropine => H(+) + NADPH + tropinone',
#  'rhea_id': '24245',
#  'rights': [{'tropinone': 'ChEBI:57851'},
#             {'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'D-glucuronate': 'ChEBI:58720'}, {'ATP': 'ChEBI:30616'}],
#  'name': 'D-glucuronate + ATP => 1-phospho-alpha-D-glucuronate + ADP + H(+)',
#  'rhea_id': '17006',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'1-phospho-alpha-D-glucuronate': 'ChEBI:57897'},
#             {'ADP': 'ChEBI:456216'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'L-ornithine': 'ChEBI:46911'},
#            {'carbamoyl phosphate': 'ChEBI:58228'}],
#  'name': 'L-ornithine + carbamoyl phosphate => L-citrulline + H(+) + phosphate',
#  'rhea_id': '19514',
#  'rights': [{'phosphate': 'ChEBI:43474'},
#             {'H(+)': 'ChEBI:15378'},
#             {'L-citrulline': 'ChEBI:57743'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'all-trans-geranylgeranyl diphosphate': 'ChEBI:58756'}],
#  'name': 'all-trans-geranylgeranyl diphosphate => cembrene C + diphosphate',
#  'rhea_id': '42989',
#  'rights': [{'diphosphate': 'ChEBI:33019'}, {'cembrene C': 'ChEBI:82798'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'1,4-dihydroxy-2-naphthoyl-CoA': 'ChEBI:58897'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': '1,4-dihydroxy-2-naphthoyl-CoA + H2O => 1,4-dihydroxy-2-naphthoate + '
#          'CoA + H(+)',
#  'rhea_id': '26310',
#  'rights': [{'CoA': 'ChEBI:57287'},
#             {'H(+)': 'ChEBI:15378'},
#             {'1,4-dihydroxy-2-naphthoate': 'ChEBI:11173'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(6S)-10-formyltetrahydrofolate': 'ChEBI:57454'},
#            {'L-methionyl-tRNA(fMet)': 'ChEBI:78530'}],
#  'name': '(6S)-10-formyltetrahydrofolate + L-methionyl-tRNA(fMet) => '
#          '(6S)-5,6,7,8-tetrahydrofolate + N-formyl-L-methionyl-tRNA(fMet) + '
#          'H(+)',
#  'rhea_id': '24381',
#  'rights': [{'N-formyl-L-methionyl-tRNA(fMet)': 'ChEBI:78844'},
#             {'(6S)-5,6,7,8-tetrahydrofolate': 'ChEBI:57453'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {'fluoroacetaldehyde': 'ChEBI:14272'},
#            {'NAD(+)': 'ChEBI:57540'}],
#  'name': 'fluoroacetaldehyde + H2O + NAD(+) => fluoroacetate + 2 H(+) + NADH',
#  'rhea_id': '16678',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'fluoroacetate': 'ChEBI:18172'},
#             {'NADH': 'ChEBI:57945'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{"3-methoxy-4',5-dihydroxy-trans-stilbene": 'ChEBI:63672'},
#            {'S-adenosyl-L-methionine': 'ChEBI:59789'}],
#  'name': "3-methoxy-4',5-dihydroxy-trans-stilbene + S-adenosyl-L-methionine => "
#          'S-adenosyl-L-homocysteine + H(+) + pterostilbene',
#  'rhea_id': '32108',
#  'rights': [{'pterostilbene': 'ChEBI:8630'},
#             {'S-adenosyl-L-homocysteine': 'ChEBI:57856'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'1-aci-nitro-omega-(methylthio)alkane': 'ChEBI:136065'},
#            {'glutathione': 'ChEBI:57925'}],
#  'name': '1-aci-nitro-omega-(methylthio)alkane + glutathione => an '
#          '(E)-1-(glutathione-S-yl)-omega-(methylthio)alkylhydroximate + H2O',
#  'rhea_id': '52001',
#  'rights': [{'H2O': 'ChEBI:15377'},
#             {'an (E)-1-(glutathione-S-yl)-omega-(methylthio)alkylhydroximate': 'ChEBI:136061'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NH4(+)': 'ChEBI:28938'},
#            {'[ferricytochrome c]': 'ChEBI:29034'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': '6 [ferricytochrome c] + 2 H2O + NH4(+) => 6 [ferrocytochrome c] + 8 '
#          'H(+) + nitrite',
#  'rhea_id': '13090',
#  'rights': [{'nitrite': 'ChEBI:16301'},
#             {'[ferrocytochrome c]': 'ChEBI:29033'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'},
#            {'1-pyrroline-3-hydroxy-5-carboxylate': 'ChEBI:58509'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': '1-pyrroline-3-hydroxy-5-carboxylate + 2 H2O + NAD(+) => '
#          '4-hydroxy-L-glutamate + H(+) + NADH',
#  'rhea_id': '24891',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'4-hydroxy-L-glutamate': 'ChEBI:32812'},
#             {'NADH': 'ChEBI:57945'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'2-amino-2-deoxy-D-gluconate': 'ChEBI:58269'}],
#  'name': '2-amino-2-deoxy-D-gluconate => '
#          '(2Z,4S,5R)-2-amino-4,5,6-trihydroxyhex-2-enoate + H2O',
#  'rhea_id': '49537',
#  'rights': [{'(2Z,4S,5R)-2-amino-4,5,6-trihydroxyhex-2-enoate': 'ChEBI:131706'},
#             {'H2O': 'ChEBI:15377'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(2E,6E)-farnesyl diphosphate': 'ChEBI:175763'}],
#  'name': '(2E,6E)-farnesyl diphosphate => (+)-alpha-barbatene + diphosphate',
#  'rhea_id': '29500',
#  'rights': [{'diphosphate': 'ChEBI:33019'},
#             {'(+)-alpha-barbatene': 'ChEBI:61690'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADPH': 'ChEBI:57783'},
#            {'H(+)': 'ChEBI:15378'},
#            {'monacolin L carboxylate': 'ChEBI:79044'},
#            {'O2': 'ChEBI:15379'}],
#  'name': 'H(+) + monacolin L carboxylate + NADPH + O2 => H2O + monacolin J '
#          'carboxylate + NADP(+)',
#  'rhea_id': '29600',
#  'rights': [{'monacolin J carboxylate': 'ChEBI:79035'},
#             {'NADP(+)': 'ChEBI:58349'},
#             {'H2O': 'ChEBI:15377'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H(+)': 'ChEBI:15378'},
#            {'3-phenylpropanoate': 'ChEBI:51057'},
#            {'NADH': 'ChEBI:57945'},
#            {'O2': 'ChEBI:15379'}],
#  'name': '3-phenylpropanoate + H(+) + NADH + O2 => '
#          '3-(cis-5,6-dihydroxycyclohexa-1,3-dienyl)propanoate + NAD(+)',
#  'rhea_id': '20358',
#  'rights': [{'3-(cis-5,6-dihydroxycyclohexa-1,3-dienyl)propanoate': 'ChEBI:60087'},
#             {'NAD(+)': 'ChEBI:57540'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'4-carboxy-2-hydroxymuconate semialdehyde hemiacetal': 'ChEBI:61985'},
#            {'NADP(+)': 'ChEBI:58349'}],
#  'name': '4-carboxy-2-hydroxymuconate semialdehyde hemiacetal + NADP(+) => '
#          '2-oxo-2H-pyran-4,6-dicarboxylate + H(+) + NADPH',
#  'rhea_id': '29588',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'},
#             {'2-oxo-2H-pyran-4,6-dicarboxylate': 'ChEBI:58304'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'O2': 'ChEBI:15379'}, {'5-hydroxymethylfurfural': 'ChEBI:412516'}],
#  'name': '5-hydroxymethylfurfural + O2 => 2,5-diformylfuran + H2O2',
#  'rhea_id': '43505',
#  'rights': [{'2,5-diformylfuran': 'ChEBI:83385'}, {'H2O2': 'ChEBI:16240'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'cis-2-chloro-4-carboxymethylenebut-2-en-1,4-olide': 'ChEBI:57681'}],
#  'name': 'cis-2-chloro-4-carboxymethylenebut-2-en-1,4-olide => '
#          'trans-2-chloro-4-carboxymethylenebut-2-en-1,4-olide',
#  'rhea_id': '10925',
#  'rights': [{'trans-2-chloro-4-carboxymethylenebut-2-en-1,4-olide': 'ChEBI:57891'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'O2': 'ChEBI:15379'},
#            {'H2O': 'ChEBI:15377'},
#            {'urate': 'ChEBI:17775'}],
#  'name': 'H2O + O2 + urate => 5-hydroxyisourate + H2O2',
#  'rhea_id': '21369',
#  'rights': [{'5-hydroxyisourate': 'ChEBI:18072'}, {'H2O2': 'ChEBI:16240'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'carboxymethyluridine(34) in tRNA': 'ChEBI:74882'},
#            {'S-adenosyl-L-methionine': 'ChEBI:59789'}],
#  'name': 'S-adenosyl-L-methionine + carboxymethyluridine(34) in tRNA => '
#          '5-(2-methoxy-2-oxoethyl)uridine(34) in tRNA + '
#          'S-adenosyl-L-homocysteine',
#  'rhea_id': '43209',
#  'rights': [{'S-adenosyl-L-homocysteine': 'ChEBI:57856'},
#             {'5-(2-methoxy-2-oxoethyl)uridine(34) in tRNA': 'ChEBI:74851'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'}, {'(S)-carnitine': 'ChEBI:11060'}],
#  'name': '(S)-carnitine + NAD(+) => 3-dehydrocarnitine + H(+) + NADH',
#  'rhea_id': '11557',
#  'rights': [{'NADH': 'ChEBI:57945'},
#             {'3-dehydrocarnitine': 'ChEBI:57885'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'UDP-alpha-D-galactofuranose': 'ChEBI:66915'},
#            {'alpha-L-rhamnopyranosyl-(1->3)-N-acetyl-alpha-D-glucosaminyl-diphospho-trans,octacis-decaprenol': 'ChEBI:67209'}],
#  'name': 'alpha-L-rhamnopyranosyl-(1->3)-N-acetyl-alpha-D-glucosaminyl-diphospho-trans,octacis-decaprenol '
#          '+ UDP-alpha-D-galactofuranose => '
#          'beta-D-galactofuranosyl-(1->4)-alpha-L-rhamnopyranosyl-(1->3)-N-acetyl-alpha-D-glucosaminyl-diphospho-trans-octacis-decaprenol '
#          '+ H(+) + UDP',
#  'rhea_id': '34384',
#  'rights': [{'UDP': 'ChEBI:58223'},
#             {'H(+)': 'ChEBI:15378'},
#             {'beta-D-galactofuranosyl-(1->4)-alpha-L-rhamnopyranosyl-(1->3)-N-acetyl-alpha-D-glucosaminyl-diphospho-trans-octacis-decaprenol': 'ChEBI:67211'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'methyl-2-alpha-L-fucopyranosyl-beta-D-galactoside': 'ChEBI:17512'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': 'H2O + methyl-2-alpha-L-fucopyranosyl-beta-D-galactoside => L-fucose '
#          '+ methyl beta-D-galactoside',
#  'rhea_id': '10817',
#  'rights': [{'methyl beta-D-galactoside': 'ChEBI:17540'},
#             {'L-fucose': 'ChEBI:2181'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(2E,6E)-farnesyl diphosphate': 'ChEBI:175763'}],
#  'name': '(2E,6E)-farnesyl diphosphate => (-)-alpha-cuprenene + diphosphate',
#  'rhea_id': '32028',
#  'rights': [{'(-)-alpha-cuprenene': 'ChEBI:63701'},
#             {'diphosphate': 'ChEBI:33019'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'succinyl-CoA': 'ChEBI:57292'}, {'H2O': 'ChEBI:15377'}],
#  'name': 'H2O + succinyl-CoA => CoA + H(+) + succinate',
#  'rhea_id': '11517',
#  'rights': [{'succinate': 'ChEBI:30031'},
#             {'H(+)': 'ChEBI:15378'},
#             {'CoA': 'ChEBI:57287'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'UDP-N-acetyl-alpha-D-glucosamine': 'ChEBI:57705'},
#            {'beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl group': 'ChEBI:12357'}],
#  'name': 'beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl group + '
#          'UDP-N-acetyl-alpha-D-glucosamine => '
#          'N-acetyl-beta-D-glucosaminyl-(1->6)-beta-D-galactosyl-(1->4)-N-acetyl-D-glucosaminyl '
#          'group + H(+) + UDP',
#  'rhea_id': '17414',
#  'rights': [{'N-acetyl-beta-D-glucosaminyl-(1->6)-beta-D-galactosyl-(1->4)-N-acetyl-D-glucosaminyl group': 'ChEBI:16198'},
#             {'H(+)': 'ChEBI:15378'},
#             {'UDP': 'ChEBI:58223'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'3-hydroxy-3-(4-methylpent-3-en-1-yl)glutaryl-CoA': 'ChEBI:57341'}],
#  'name': '3-hydroxy-3-(4-methylpent-3-en-1-yl)glutaryl-CoA => '
#          '7-methyl-3-oxooct-6-enoyl-CoA + acetate',
#  'rhea_id': '23085',
#  'rights': [{'acetate': 'ChEBI:30089'},
#             {'7-methyl-3-oxooct-6-enoyl-CoA': 'ChEBI:71410'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'all-trans-violaxanthin': 'ChEBI:35288'},
#            {'L-ascorbate': 'ChEBI:38290'}],
#  'name': 'all-trans-violaxanthin + L-ascorbate => all-trans-antheraxanthin + '
#          'L-dehydroascorbate + H2O',
#  'rhea_id': '15354',
#  'rights': [{'L-dehydroascorbate': 'ChEBI:58539'},
#             {'H2O': 'ChEBI:15377'},
#             {'all-trans-antheraxanthin': 'ChEBI:27867'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'thiamine diphosphate': 'ChEBI:58937'}, {'ATP': 'ChEBI:30616'}],
#  'name': 'ATP + thiamine diphosphate => ADP + thiamine triphosphate',
#  'rhea_id': '11241',
#  'rights': [{'ADP': 'ChEBI:456216'}, {'thiamine triphosphate': 'ChEBI:58938'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'acetyl-CoA': 'ChEBI:57288'},
#            {'N-terminal L-seryl-[protein]': 'ChEBI:64738'}],
#  'name': 'acetyl-CoA + N-terminal L-seryl-[protein] => CoA + H(+) + N-terminal '
#          'N(alpha)-acetyl-L-seryl-[protein]',
#  'rhea_id': '50505',
#  'rights': [{'N-terminal N(alpha)-acetyl-L-seryl-[protein]': 'ChEBI:83690'},
#             {'CoA': 'ChEBI:57287'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {'6-hydroxynicotinate': 'ChEBI:57664'},
#            {'O2': 'ChEBI:15379'}],
#  'name': '6-hydroxynicotinate + H2O + O2 => 2,6-dihydroxynicotinate + H2O2',
#  'rhea_id': '22809',
#  'rights': [{'H2O2': 'ChEBI:16240'},
#             {'2,6-dihydroxynicotinate': 'ChEBI:58780'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'heme b': 'ChEBI:60344'},
#            {'ATP': 'ChEBI:30616'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': 'ATP + H2O + heme b(in) => ADP + H(+) + heme b(out) + phosphate',
#  'rhea_id': '19262',
#  'rights': [{'phosphate': 'ChEBI:43474'},
#             {'heme b': 'ChEBI:60344'},
#             {'H(+)': 'ChEBI:15378'},
#             {'ADP': 'ChEBI:456216'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'},
#            {'(1R,2S)-1,2-dihydronaphthalene-1,2-diol': 'ChEBI:44343'}],
#  'name': '(1R,2S)-1,2-dihydronaphthalene-1,2-diol + NAD(+) => H(+) + NADH + '
#          'naphthalene-1,2-diol',
#  'rhea_id': '11833',
#  'rights': [{'naphthalene-1,2-diol': 'ChEBI:17435'},
#             {'H(+)': 'ChEBI:15378'},
#             {'NADH': 'ChEBI:57945'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'ATP': 'ChEBI:30616'},
#            {'holo-[ACP]': 'ChEBI:64479'},
#            {'a long-chain fatty acid': 'ChEBI:57560'}],
#  'name': 'a long-chain fatty acid + ATP + holo-[ACP] => a long-chain fatty '
#          'acyl-[ACP] + AMP + diphosphate',
#  'rhea_id': '45589',
#  'rights': [{'AMP': 'ChEBI:456215'},
#             {'a long-chain fatty acyl-[ACP]': 'ChEBI:133243'},
#             {'diphosphate': 'ChEBI:33019'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'AH2': 'ChEBI:17499'},
#            {'(5Z,8Z,11Z,14Z)-eicosatetraenoate': 'ChEBI:32395'},
#            {'O2': 'ChEBI:15379'}],
#  'name': '(5Z,8Z,11Z,14Z)-eicosatetraenoate + AH2 + 2 O2 => A + H2O + '
#          'prostaglandin H2',
#  'rhea_id': '23729',
#  'rights': [{'prostaglandin H2': 'ChEBI:57405'},
#             {'H2O': 'ChEBI:15377'},
#             {'A': 'ChEBI:13193'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'2-methyl-1-(2,4,6-trihydroxyphenyl)butan-1-one': 'ChEBI:134326'},
#            {'dimethylallyl diphosphate': 'ChEBI:57623'}],
#  'name': '2-methyl-1-(2,4,6-trihydroxyphenyl)butan-1-one + dimethylallyl '
#          'diphosphate => 4-prenylphlormethylbutanophenone + diphosphate',
#  'rhea_id': '51769',
#  'rights': [{'4-prenylphlormethylbutanophenone': 'ChEBI:134340'},
#             {'diphosphate': 'ChEBI:33019'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADPH': 'ChEBI:57783'},
#            {'O2': 'ChEBI:15379'},
#            {'4-hydroxybenzoate': 'ChEBI:17879'},
#            {'H(+)': 'ChEBI:15378'}],
#  'name': '4-hydroxybenzoate + H(+) + NADPH + O2 => 3,4-dihydroxybenzoate + H2O '
#          '+ NADP(+)',
#  'rhea_id': '19478',
#  'rights': [{'H2O': 'ChEBI:15377'},
#             {'NADP(+)': 'ChEBI:58349'},
#             {'3,4-dihydroxybenzoate': 'ChEBI:36241'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'O2': 'ChEBI:15379'},
#            {'N(1)-acetylspermidine': 'ChEBI:58324'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': 'N(1)-acetylspermidine + H2O + O2 => 4-acetamidobutanal + H2O2 + '
#          'propane-1,3-diamine',
#  'rhea_id': '25865',
#  'rights': [{'4-acetamidobutanal': 'ChEBI:7386'},
#             {'propane-1,3-diamine': 'ChEBI:57484'},
#             {'H2O2': 'ChEBI:16240'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADP(+)': 'ChEBI:58349'}, {'10-deoxysarpagine': 'ChEBI:16060'}],
#  'name': '10-deoxysarpagine + NADP(+) => H(+) + NADPH + vellosimine',
#  'rhea_id': '20030',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'},
#             {'vellosimine': 'ChEBI:18057'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'N,N-dihydroxy-L-phenylalanine': 'ChEBI:58727'},
#            {'H(+)': 'ChEBI:15378'}],
#  'name': 'N,N-dihydroxy-L-phenylalanine + H(+) => (E)-phenylacetaldehyde oxime '
#          '+ CO2 + H2O',
#  'rhea_id': '25001',
#  'rights': [{'(E)-phenylacetaldehyde oxime': 'ChEBI:47793'},
#             {'CO2': 'ChEBI:16526'},
#             {'H2O': 'ChEBI:15377'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'2-dehydro-3-deoxy-D-glucarate': 'ChEBI:58098'}],
#  'name': '2-dehydro-3-deoxy-D-glucarate => 2-hydroxy-3-oxopropanoate + '
#          'pyruvate',
#  'rhea_id': '10269',
#  'rights': [{'pyruvate': 'ChEBI:15361'},
#             {'2-hydroxy-3-oxopropanoate': 'ChEBI:57978'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'L-arogenate': 'ChEBI:58180'}, {'oxaloacetate': 'ChEBI:16452'}],
#  'name': 'L-arogenate + oxaloacetate => L-aspartate + prephenate',
#  'rhea_id': '20446',
#  'rights': [{'L-aspartate': 'ChEBI:29991'}, {'prephenate': 'ChEBI:29934'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'beta-nicotinamide D-ribonucleotide': 'ChEBI:14649'},
#            {'ATP': 'ChEBI:30616'},
#            {'H(+)': 'ChEBI:15378'}],
#  'name': 'beta-nicotinamide D-ribonucleotide + ATP + H(+) => diphosphate + '
#          'NAD(+)',
#  'rhea_id': '21361',
#  'rights': [{'diphosphate': 'ChEBI:33019'}, {'NAD(+)': 'ChEBI:57540'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'3-hydroxypropanoyl-CoA': 'ChEBI:58528'}],
#  'name': '3-hydroxypropanoyl-CoA => acryloyl-CoA + H2O',
#  'rhea_id': '26519',
#  'rights': [{'H2O': 'ChEBI:15377'}, {'acryloyl-CoA': 'ChEBI:57367'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'S-adenosyl-L-homocysteine': 'ChEBI:57856'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': 'S-adenosyl-L-homocysteine + H2O => L-homocysteine + adenosine',
#  'rhea_id': '21709',
#  'rights': [{'adenosine': 'ChEBI:16335'}, {'L-homocysteine': 'ChEBI:58199'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O2': 'ChEBI:16240'}],
#  'name': '2 H2O2 => 2 H2O + O2',
#  'rhea_id': '20310',
#  'rights': [{'H2O': 'ChEBI:15377'}, {'O2': 'ChEBI:15379'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {"9-ribosyl-trans-zeatin 5'-phosphate": 'ChEBI:87947'}],
#  'name': "9-ribosyl-trans-zeatin 5'-phosphate + H2O => D-ribofuranose "
#          '5-phosphate + trans-zeatin',
#  'rhea_id': '48565',
#  'rights': [{'trans-zeatin': 'ChEBI:16522'},
#             {'D-ribofuranose 5-phosphate': 'ChEBI:78346'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'trans-aconitate': 'ChEBI:15708'}],
#  'name': 'trans-aconitate => cis-aconitate',
#  'rhea_id': '17266',
#  'rights': [{'cis-aconitate': 'ChEBI:16383'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'tRNA(Leu)': 'ChEBI:78442'},
#            {'L-leucine': 'ChEBI:57427'},
#            {'ATP': 'ChEBI:30616'}],
#  'name': 'L-leucine + ATP + tRNA(Leu) => L-leucyl-tRNA(Leu) + AMP + '
#          'diphosphate',
#  'rhea_id': '11689',
#  'rights': [{'diphosphate': 'ChEBI:33019'},
#             {'AMP': 'ChEBI:456215'},
#             {'L-leucyl-tRNA(Leu)': 'ChEBI:78494'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'L-glutamate': 'ChEBI:29985'},
#            {'methylamine': 'ChEBI:59338'},
#            {'ATP': 'ChEBI:30616'}],
#  'name': 'L-glutamate + ATP + methylamine => N(5)-methyl-L-glutamine + ADP + '
#          'H(+) + phosphate',
#  'rhea_id': '17118',
#  'rights': [{'phosphate': 'ChEBI:43474'},
#             {'N(5)-methyl-L-glutamine': 'ChEBI:58200'},
#             {'H(+)': 'ChEBI:15378'},
#             {'ADP': 'ChEBI:456216'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(2R)-2-hydroxy-2-methylbutanenitrile': 'ChEBI:60908'}],
#  'name': '(2R)-2-hydroxy-2-methylbutanenitrile => butan-2-one + hydrogen '
#          'cyanide',
#  'rhea_id': '28171',
#  'rights': [{'butan-2-one': 'ChEBI:28398'},
#             {'hydrogen cyanide': 'ChEBI:18407'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'sphing-4-enine 1-phosphate': 'ChEBI:60119'}],
#  'name': 'sphing-4-enine 1-phosphate => (2E)-hexadecenal + phosphoethanolamine',
#  'rhea_id': '33508',
#  'rights': [{'(2E)-hexadecenal': 'ChEBI:17585'},
#             {'phosphoethanolamine': 'ChEBI:58190'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'}, {'D-ribitol': 'ChEBI:15963'}],
#  'name': 'D-ribitol + NAD(+) => D-ribulose + H(+) + NADH',
#  'rhea_id': '20054',
#  'rights': [{'NADH': 'ChEBI:57945'},
#             {'D-ribulose': 'ChEBI:17173'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'CMP-N-acetyl-beta-neuraminate': 'ChEBI:57812'},
#            {'beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-N-acylsphing-4-enine': 'ChEBI:17950'}],
#  'name': 'beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-N-acylsphing-4-enine '
#          '+ CMP-N-acetyl-beta-neuraminate => '
#          'alpha-N-acetylneuraminosyl-(2->3)-beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-N-acylsphing-4-enine '
#          '+ CMP + H(+)',
#  'rhea_id': '18418',
#  'rights': [{'CMP': 'ChEBI:60377'},
#             {'H(+)': 'ChEBI:15378'},
#             {'alpha-N-acetylneuraminosyl-(2->3)-beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-N-acylsphing-4-enine': 'ChEBI:60065'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'ATP': 'ChEBI:30616'},
#            {'adenosylcob(III)yrate': 'ChEBI:58504'},
#            {'(R)-1-aminopropan-2-yl phosphate': 'ChEBI:58563'}],
#  'name': '(R)-1-aminopropan-2-yl phosphate + adenosylcob(III)yrate + ATP => '
#          'adenosylcob(III)inamide phosphate + ADP + H(+) + phosphate',
#  'rhea_id': '21897',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'ADP': 'ChEBI:456216'},
#             {'phosphate': 'ChEBI:43474'},
#             {'adenosylcob(III)inamide phosphate': 'ChEBI:58502'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'},
#            {'(R)-1-aminopropan-2-ol': 'ChEBI:42677'}],
#  'name': '(R)-1-aminopropan-2-ol + NAD(+) => aminoacetone + H(+) + NADH',
#  'rhea_id': '16518',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'NADH': 'ChEBI:57945'},
#             {'aminoacetone': 'ChEBI:58320'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'N-formyl-L-kynurenine': 'ChEBI:58629'}, {'H2O': 'ChEBI:15377'}],
#  'name': 'N-formyl-L-kynurenine + H2O => L-kynurenine + formate + H(+)',
#  'rhea_id': '13010',
#  'rights': [{'formate': 'ChEBI:15740'},
#             {'H(+)': 'ChEBI:15378'},
#             {'L-kynurenine': 'ChEBI:57959'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'}, {'tartrate': 'ChEBI:30929'}],
#  'name': 'NAD(+) + tartrate => 2-hydroxy-3-oxosuccinate + H(+) + NADH',
#  'rhea_id': '18854',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'2-hydroxy-3-oxosuccinate': 'ChEBI:58265'},
#             {'NADH': 'ChEBI:57945'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {'2-hydroxy-5-(methylsulfanyl)-3-oxopent-1-enyl phosphate': 'ChEBI:59505'}],
#  'name': '2-hydroxy-5-(methylsulfanyl)-3-oxopent-1-enyl phosphate + H2O => '
#          'acireductone + phosphate',
#  'rhea_id': '14482',
#  'rights': [{'acireductone': 'ChEBI:49252'}, {'phosphate': 'ChEBI:43474'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'4-coumarate': 'ChEBI:32373'},
#            {'ATP': 'ChEBI:30616'},
#            {'CoA': 'ChEBI:57287'}],
#  'name': '4-coumarate + ATP + CoA => 4-coumaroyl-CoA + AMP + diphosphate',
#  'rhea_id': '19642',
#  'rights': [{'AMP': 'ChEBI:456215'},
#             {'diphosphate': 'ChEBI:33019'},
#             {'4-coumaroyl-CoA': 'ChEBI:57355'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'1-(5-phospho-beta-D-ribosyl)-ATP': 'ChEBI:73183'},
#            {'diphosphate': 'ChEBI:33019'}],
#  'name': '1-(5-phospho-beta-D-ribosyl)-ATP + diphosphate => '
#          '5-phospho-alpha-D-ribose 1-diphosphate + ATP',
#  'rhea_id': '18474',
#  'rights': [{'5-phospho-alpha-D-ribose 1-diphosphate': 'ChEBI:58017'},
#             {'ATP': 'ChEBI:30616'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADP(+)': 'ChEBI:58349'},
#            {'3alpha-hydroxyglycyrrhetinate': 'ChEBI:57729'}],
#  'name': '3alpha-hydroxyglycyrrhetinate + NADP(+) => 3-oxoglycyrrhetinate + '
#          'H(+) + NADPH',
#  'rhea_id': '20817',
#  'rights': [{'3-oxoglycyrrhetinate': 'ChEBI:57760'},
#             {'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'acetyl-CoA': 'ChEBI:57288'},
#            {'an aliphatic alcohol': 'ChEBI:2571'}],
#  'name': 'acetyl-CoA + an aliphatic alcohol => an acetyl ester + CoA',
#  'rhea_id': '17230',
#  'rights': [{'an acetyl ester': 'ChEBI:47622'}, {'CoA': 'ChEBI:57287'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADP(+)': 'ChEBI:58349'},
#            {'3-oxopropanoate': 'ChEBI:33190'},
#            {'CoA': 'ChEBI:57287'}],
#  'name': '3-oxopropanoate + CoA + NADP(+) => H(+) + malonyl-CoA + NADPH',
#  'rhea_id': '26447',
#  'rights': [{'malonyl-CoA': 'ChEBI:57384'},
#             {'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'}, {'protodioscin': 'ChEBI:8588'}],
#  'name': 'H2O + protodioscin => 26-deglucoprotodioscin + D-glucose',
#  'rhea_id': '37896',
#  'rights': [{'26-deglucoprotodioscin': 'ChEBI:74026'},
#             {'D-glucose': 'ChEBI:4167'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'},
#            {'1,2-diacyl-sn-glycerol 3-diphosphate': 'ChEBI:59996'}],
#  'name': '1,2-diacyl-sn-glycerol 3-diphosphate + H2O => a '
#          '1,2-diacyl-sn-glycero-3-phosphate + H(+) + phosphate',
#  'rhea_id': '27450',
#  'rights': [{'phosphate': 'ChEBI:43474'},
#             {'H(+)': 'ChEBI:15378'},
#             {'a 1,2-diacyl-sn-glycero-3-phosphate': 'ChEBI:58608'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'octanoyl-[ACP]': 'ChEBI:78463'},
#            {'[protein]-L-lysine': 'ChEBI:29969'}],
#  'name': '[protein]-L-lysine + octanoyl-[ACP] => '
#          '[protein]-N(6)-octanoyl-L-lysine + H(+) + holo-[ACP]',
#  'rhea_id': '17666',
#  'rights': [{'holo-[ACP]': 'ChEBI:64479'},
#             {'H(+)': 'ChEBI:15378'},
#             {'[protein]-N(6)-octanoyl-L-lysine': 'ChEBI:78809'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADP(+)': 'ChEBI:58349'},
#            {'13,14-dihydro-15-oxo-prostaglandin E2': 'ChEBI:57402'}],
#  'name': '13,14-dihydro-15-oxo-prostaglandin E2 + NADP(+) => '
#          '15-oxo-prostaglandin E2 + H(+) + NADPH',
#  'rhea_id': '11913',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'15-oxo-prostaglandin E2': 'ChEBI:57400'},
#             {'NADPH': 'ChEBI:57783'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'pseudotropine': 'ChEBI:57493'}, {'an acyl-CoA': 'ChEBI:58342'}],
#  'name': 'an acyl-CoA + pseudotropine => O-acylpseudotropine + CoA + H(+)',
#  'rhea_id': '25521',
#  'rights': [{'CoA': 'ChEBI:57287'},
#             {'O-acylpseudotropine': 'ChEBI:52657'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'homogentisate': 'ChEBI:16169'},
#            {'H(+)': 'ChEBI:15378'},
#            {'phytyl diphosphate': 'ChEBI:75434'}],
#  'name': 'H(+) + homogentisate + phytyl diphosphate => '
#          '2-methyl-6-phytyl-1,4-benzene-1,4-diol + CO2 + diphosphate',
#  'rhea_id': '37976',
#  'rights': [{'CO2': 'ChEBI:16526'},
#             {'2-methyl-6-phytyl-1,4-benzene-1,4-diol': 'ChEBI:75920'},
#             {'diphosphate': 'ChEBI:33019'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'dTDP-3-amino-3,6-dideoxy-alpha-D-galactopyranose': 'ChEBI:63305'},
#            {'acetyl-CoA': 'ChEBI:57288'}],
#  'name': 'acetyl-CoA + dTDP-3-amino-3,6-dideoxy-alpha-D-galactopyranose => CoA '
#          '+ dTDP-3-acetamido-3,6-dideoxy-alpha-D-galactopyranose + H(+)',
#  'rhea_id': '32096',
#  'rights': [{'dTDP-3-acetamido-3,6-dideoxy-alpha-D-galactopyranose': 'ChEBI:63676'},
#             {'H(+)': 'ChEBI:15378'},
#             {'CoA': 'ChEBI:57287'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'ATP': 'ChEBI:30616'},
#            {"(RNA)-3'-(3'-phospho-ribonucleoside)": 'ChEBI:83062'}],
#  'name': "(RNA)-3'-(3'-phospho-ribonucleoside) + ATP => "
#          "(RNA)-3'-(2',3'-cyclophospho)-ribonucleoside + AMP + diphosphate",
#  'rhea_id': '23977',
#  'rights': [{'AMP': 'ChEBI:456215'},
#             {"(RNA)-3'-(2',3'-cyclophospho)-ribonucleoside": 'ChEBI:83064'},
#             {'diphosphate': 'ChEBI:33019'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{"4'-apo-beta-carotenal": 'ChEBI:53157'},
#            {'H2O': 'ChEBI:15377'},
#            {'NAD(+)': 'ChEBI:57540'}],
#  'name': "4'-apo-beta-carotenal + H2O + NAD(+) => 2 H(+) + NADH + "
#          'neurosporaxanthin',
#  'rhea_id': '31516',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'NADH': 'ChEBI:57945'},
#             {'neurosporaxanthin': 'ChEBI:63069'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'3-amino-2-oxopropyl phosphate': 'ChEBI:57279'},
#            {'1-deoxy-D-xylulose 5-phosphate': 'ChEBI:57792'}],
#  'name': '1-deoxy-D-xylulose 5-phosphate + 3-amino-2-oxopropyl phosphate => 2 '
#          "H2O + H(+) + phosphate + pyridoxine 5'-phosphate",
#  'rhea_id': '15266',
#  'rights': [{'phosphate': 'ChEBI:43474'},
#             {'H(+)': 'ChEBI:15378'},
#             {"pyridoxine 5'-phosphate": 'ChEBI:58589'},
#             {'H2O': 'ChEBI:15377'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NAD(+)': 'ChEBI:57540'},
#            {'(2R,3S)-3-methylmalate': 'ChEBI:58511'}],
#  'name': '(2R,3S)-3-methylmalate + NAD(+) => 2-oxobutanoate + CO2 + NADH',
#  'rhea_id': '32716',
#  'rights': [{'CO2': 'ChEBI:16526'},
#             {'2-oxobutanoate': 'ChEBI:16763'},
#             {'NADH': 'ChEBI:57945'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'}, {'D-glucurono-6,2-lactone': 'ChEBI:17039'}],
#  'name': 'D-glucurono-6,2-lactone + H2O => D-glucuronate + H(+)',
#  'rhea_id': '13338',
#  'rights': [{'H(+)': 'ChEBI:15378'}, {'D-glucuronate': 'ChEBI:58720'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'(3R)-3-hydroxy-D-aspartate': 'ChEBI:60898'}],
#  'name': '(3R)-3-hydroxy-D-aspartate => NH4(+) + oxaloacetate',
#  'rhea_id': '27943',
#  'rights': [{'oxaloacetate': 'ChEBI:16452'}, {'NH4(+)': 'ChEBI:28938'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'L-gulonate': 'ChEBI:13115'}, {'NAD(+)': 'ChEBI:57540'}],
#  'name': 'L-gulonate + NAD(+) => keto-D-fructuronate + H(+) + NADH',
#  'rhea_id': '43497',
#  'rights': [{'NADH': 'ChEBI:57945'},
#             {'H(+)': 'ChEBI:15378'},
#             {'keto-D-fructuronate': 'ChEBI:59881'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'S-adenosyl-L-methionine': 'ChEBI:59789'},
#            {'resorcinol': 'ChEBI:27810'}],
#  'name': 'S-adenosyl-L-methionine + resorcinol => 3-methoxyphenol + '
#          'S-adenosyl-L-homocysteine + H(+)',
#  'rhea_id': '26322',
#  'rights': [{'3-methoxyphenol': 'ChEBI:52678'},
#             {'S-adenosyl-L-homocysteine': 'ChEBI:57856'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'L-glutamine': 'ChEBI:58359'},
#            {'3-amino-2,3-dideoxy-scyllo-inosose': 'ChEBI:65002'}],
#  'name': '3-amino-2,3-dideoxy-scyllo-inosose + L-glutamine => '
#          '2-deoxystreptamine + 2-oxoglutaramate',
#  'rhea_id': '34152',
#  'rights': [{'2-deoxystreptamine': 'ChEBI:65069'},
#             {'2-oxoglutaramate': 'ChEBI:16769'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'4-(dimethylamino)azobenzene': 'ChEBI:17903'},
#            {'H2O': 'ChEBI:15377'},
#            {'NADP(+)': 'ChEBI:58349'}],
#  'name': '4-(dimethylamino)azobenzene + H2O + NADP(+) => '
#          '4-(dimethylamino)phenylazoxybenzene + H(+) + NADPH',
#  'rhea_id': '19790',
#  'rights': [{'4-(dimethylamino)phenylazoxybenzene': 'ChEBI:17467'},
#             {'H(+)': 'ChEBI:15378'},
#             {'NADPH': 'ChEBI:57783'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'hexadecanoyl-[ACP]': 'ChEBI:78483'},
#            {'H(+)': 'ChEBI:15378'},
#            {'O2': 'ChEBI:15379'},
#            {'reduced [2Fe-2S]-[ferredoxin]': 'ChEBI:33738'}],
#  'name': '2 H(+) + hexadecanoyl-[ACP] + O2 + 2 reduced [2Fe-2S]-[ferredoxin] '
#          '=> (6Z)-hexadecenoyl-[ACP] + 2 H2O + 2 oxidized '
#          '[2Fe-2S]-[ferredoxin]',
#  'rhea_id': '46417',
#  'rights': [{'(6Z)-hexadecenoyl-[ACP]': 'ChEBI:86110'},
#             {'H2O': 'ChEBI:15377'},
#             {'oxidized [2Fe-2S]-[ferredoxin]': 'ChEBI:33737'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'D-glyceraldehyde 3-phosphate': 'ChEBI:59776'}],
#  'name': 'D-glyceraldehyde 3-phosphate => dihydroxyacetone phosphate',
#  'rhea_id': '18586',
#  'rights': [{'dihydroxyacetone phosphate': 'ChEBI:57642'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'S-adenosyl-L-methionine': 'ChEBI:59789'},
#            {'L-olivosyl-oleandolide': 'ChEBI:29614'}],
#  'name': 'S-adenosyl-L-methionine + L-olivosyl-oleandolide => '
#          'S-adenosyl-L-homocysteine + L-oleandrosyl-oleandolide + H(+)',
#  'rhea_id': '31624',
#  'rights': [{'H(+)': 'ChEBI:15378'},
#             {'L-oleandrosyl-oleandolide': 'ChEBI:29613'},
#             {'S-adenosyl-L-homocysteine': 'ChEBI:57856'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'feruloyl-CoA': 'ChEBI:57276'}, {'L-quinate': 'ChEBI:29751'}],
#  'name': 'L-quinate + feruloyl-CoA => 4-O-feruloyl-D-quinate + CoA',
#  'rhea_id': '15022',
#  'rights': [{'4-O-feruloyl-D-quinate': 'ChEBI:60078'}, {'CoA': 'ChEBI:57287'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'2-hydroxy-2-methylpropanal': 'ChEBI:131846'},
#            {'H2O': 'ChEBI:15377'},
#            {'NAD(+)': 'ChEBI:57540'}],
#  'name': '2-hydroxy-2-methylpropanal + H2O + NAD(+) => 2-hydroxyisobutanoate + '
#          '2 H(+) + NADH',
#  'rhea_id': '49617',
#  'rights': [{'2-hydroxyisobutanoate': 'ChEBI:19641'},
#             {'NADH': 'ChEBI:57945'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'methanethiol': 'ChEBI:16007'}, {'coenzyme M': 'ChEBI:58319'}],
#  'name': 'coenzyme M + methanethiol => H(+) + hydrogen sulfide + '
#          'methyl-coenzyme M',
#  'rhea_id': '32668',
#  'rights': [{'hydrogen sulfide': 'ChEBI:29919'},
#             {'H(+)': 'ChEBI:15378'},
#             {'methyl-coenzyme M': 'ChEBI:58286'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'all-trans-geranylgeranyl diphosphate': 'ChEBI:58756'}],
#  'name': 'all-trans-geranylgeranyl diphosphate => ent-copalyl diphosphate',
#  'rhea_id': '14842',
#  'rights': [{'ent-copalyl diphosphate': 'ChEBI:58553'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'cis-3-hydroxy-L-proline': 'ChEBI:60041'}],
#  'name': 'cis-3-hydroxy-L-proline => 1-pyrroline-2-carboxylate + H2O',
#  'rhea_id': '47625',
#  'rights': [{'H2O': 'ChEBI:15377'},
#             {'1-pyrroline-2-carboxylate': 'ChEBI:39785'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'H2O': 'ChEBI:15377'}, {'streptothricin D': 'ChEBI:60829'}],
#  'name': 'H2O + streptothricin D => streptothricin D acid',
#  'rhea_id': '28143',
#  'rights': [{'streptothricin D acid': 'ChEBI:60839'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'3-methylbutanoyl-CoA': 'ChEBI:57345'},
#            {'S-adenosyl-L-methionine': 'ChEBI:59789'}],
#  'name': '3-methylbutanoyl-CoA + S-adenosyl-L-methionine => '
#          "N-isovaleryl-L-homoserine lactone + S-methyl-5'-thioadenosine + CoA "
#          '+ H(+)',
#  'rhea_id': '37472',
#  'rights': [{'CoA': 'ChEBI:57287'},
#             {'N-isovaleryl-L-homoserine lactone': 'ChEBI:74958'},
#             {"S-methyl-5'-thioadenosine": 'ChEBI:17509'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'fumarate': 'ChEBI:29806'}, {'(S)-dihydroorotate': 'ChEBI:30864'}],
#  'name': '(S)-dihydroorotate + fumarate => orotate + succinate',
#  'rhea_id': '30060',
#  'rights': [{'orotate': 'ChEBI:30839'}, {'succinate': 'ChEBI:30031'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'dalnigrein beta-D-apiofuranosyl-(1->6)-beta-D-glucopyranoside': 'ChEBI:55550'},
#            {'H2O': 'ChEBI:15377'}],
#  'name': 'dalnigrein beta-D-apiofuranosyl-(1->6)-beta-D-glucopyranoside + H2O '
#          '=> beta-D-apiofuranosyl-(1->6)-D-glucopyranose + dalnigrein + H(+)',
#  'rhea_id': '21489',
#  'rights': [{'beta-D-apiofuranosyl-(1->6)-D-glucopyranose': 'ChEBI:55406'},
#             {'dalnigrein': 'ChEBI:83859'},
#             {'H(+)': 'ChEBI:15378'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'NADH': 'ChEBI:57945'},
#            {'H(+)': 'ChEBI:15378'},
#            {'UDP-2-acetamido-2,6-dideoxy-beta-L-arabino-hex-4-ulose': 'ChEBI:60101'}],
#  'name': 'H(+) + NADH + UDP-2-acetamido-2,6-dideoxy-beta-L-arabino-hex-4-ulose '
#          '=> NAD(+) + UDP-2-acetamido-2,6-dideoxy-beta-L-talose',
#  'rhea_id': '40160',
#  'rights': [{'NAD(+)': 'ChEBI:57540'},
#             {'UDP-2-acetamido-2,6-dideoxy-beta-L-talose': 'ChEBI:62372'}]}
# {'direction': 'left to right',
#  'ec_number': '1',
#  'lefts': [{'monoanhydrobacterioruberin': 'ChEBI:87122'}],
#  'name': 'monoanhydrobacterioruberin => bisanhydrobacterioruberin + H2O',
#  'rhea_id': '47273',
#  'rights': [{'H2O': 'ChEBI:15377'},
#             {'bisanhydrobacterioruberin': 'ChEBI:87121'}]}
